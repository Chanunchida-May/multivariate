# %% [markdown]
# <a href="https://colab.research.google.com/github/Chanunchida-May/multivariate/blob/main/MVA001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scalar, Vector,Matrix

# %% [markdown]
# ###Scalar

# %%
import numpy as np

# %%
scalar_a = 10  #scalar
print(scalar_a)
# Out:
# 10

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Vector

# %%
vector_b = np.zeros([2,1]) #vector
vector_b[0,0] = 1
vector_b[1,0] = 3
print(vector_b)
print(vector_b.shape)
# Out:
# [[1.]
#  [3.]]
# (2, 1)

# %%
vector_c = np.array([[1],[3]])
print(vector_c)
print(vector_c.shape)
# Out:
# [[1]
#  [3]]
# (2, 1)

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(vector_b[0,0],vector_b[1,0],'or')

# %% [markdown]
# ขนาดของ vector คำนวณได้โดย พีทาโกรัส

# %%
vector_b_size = ((vector_b[0,0]**2) + (vector_b[1,0]**2))**0.5 # ** คือยกกำลัง
print(vector_b_size)
# Out:
# 3.1622776601683795

# %%
plt.quiver(0,0,vector_b[0,0],vector_b[1,0])

# %% [markdown]
# ###Matrix

# %%
matrix_d = np.array([[2,3],[1,4],[-1,1]])
print(matrix_d)
# Out:
# [[ 2  3]
#  [ 1  4]
#  [-1  1]]

# %%
matrix_d = matrix_d.T
print(matrix_d)
# Out:
# [[ 2  1 -1]
#  [ 3  4  1]]

# %%
matrix_d[0,:]
# Out:
# array([ 2,  1, -1])

# %%
plt.plot(matrix_d[0,:],matrix_d[1,:],'or') ##plot(ค่าX, ค่าy, หน้าตาของจุด)
plt.plot(0,0, '.b') #plotค่า
plt.plot([0,0],[-1,5],'o:b')
plt.plot([-1.5,2.5],[0,0],':b') #bคือสีคือเส้น เว็บplt plotลิ้งค์เเรก

# %% [markdown]
# ###Transpose

# %%
A = np.array([[3,-1,2],[1,5,4]])
print(A)
# Out:
# [[ 3 -1  2]
#  [ 1  5  4]]

# %%
A.T
# Out:
# array([[ 3,  1],
#        [-1,  5],
#        [ 2,  4]])

# %% [markdown]
# ###Matrix Multiply

# %% [markdown]
# $B = A*A'$

# %%
B = np.dot(A,A.T)
print(B)
# Out:
# [[14  6]
#  [ 6 42]]

# %% [markdown]
# ###Determinant

# %% [markdown]
#  $Det(B)$

# %%
np.linalg.det(B)
# Out:
# 551.9999999999998

# %% [markdown]
# linalg = liner algebra

# %% [markdown]
# # การคูณ Matrix $B.v$ คือ การทำ linear transformation

# %% [markdown]
# matrix algebre เพิ่มเติม

# %%
plt.plot([0,1],[0,1], '-r') ##vector [1,1]
plt.plot(0,0, '.b') 
plt.plot([0,0],[-1,5],'o:b')
plt.plot([-1.5,2.5],[0,0],':b')

# %%
B = np.array([[1,2],[3,4]])
B
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
v = np.array([[1],[1]])
v
# Out:
# array([[1],
#        [1]])

# %%
Bv = np.dot(B,np.array([[1],[1]]))
Bv
# Out:
# array([[3],
#        [7]])

# %%
plt.plot([0,Bv[0,0]],[0,Bv[1,0]],'-g') # vector [1,1]
plt.plot([0,1],[0,1],'-r') 
plt.plot(0,0,'.k')
plt.plot([0,0],[-1,5],'^:b')
plt.plot([-2,2.5],[0,0],'>:b')

# %% [markdown]
# Detterminant ของ Matrix(Det(B)) คือพื้นที่ของ Unit vector ที่ถูกเปลี่ยนเเปลงไป โดย Matrix นั้นๆ

# %%
plt.plot([0,Bv[0,0]],[0,Bv[1,0]], '-g') ##vector BV
plt.plot([3,3],[7,0], ':g') ## วางจุดไข่ปลา พื้นที่BV
plt.plot([3,0],[7,7], ':g')  ##วางจุดไข่ปลา พื้นที่BV
plt.plot([0,1],[0,1], '-r')  ##vector v ([1,1])
plt.plot([1,1],[1,0], ':r')  ## วางจุดไข่ปลาของพื้นที่ V
plt.plot([1,0],[1,1], ':r')  ##วางจุดไข่ปลาของพื้นที่ V
plt.plot(0,0,'.b')
plt.plot([0,0],[-1,8],'^:k')
plt.plot([-1.5,3.5],[0,0],'>:k')

# %% [markdown]
# Identity matrix ($I$)
#
# $BI = B = IB$

# %%
iden2 = np.identity(2)

# %%
B
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.dot(B,iden2)
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
C = np.array([[-1,2],[2,4]])
C
# Out:
# array([[-1,  2],
#        [ 2,  4]])

# %%
np.dot(B,C)
# Out:
# array([[ 3, 10],
#        [ 5, 22]])

# %%
np.dot(C,B)
# Out:
# array([[ 5,  6],
#        [14, 20]])

# %% [markdown]
# ควิซในห้อง

# %%
A = np.array([[3,7,2],[1,4,-7],[6,5,1]])
print(A)
# Out:
# [[ 3  7  2]
#  [ 1  4 -7]
#  [ 6  5  1]]

# %%
A = matrix_A.T
print(A)
# Out:
# [[ 3  7  2]
#  [ 1  4 -7]
#  [ 6  5  1]]

# %%
np.linalg.det(A)
# Out:
# -221.99999999999997

# %% [markdown]
# Eigen value กับ Eigen vector
#
# Eigen value ($\lambda$)-> $|A-\lambda I| = 0$ (latex)
# Eigen vector ($x$) -> $Ax = \lambda x$

# %% [markdown]
# ## HW 5 หา Eigen value กับ Eigen **vector**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
D = np.array([[1,0],[1,3]])
D
# Out:
# array([[1, 0],
#        [1, 3]])

# %% [markdown]
# Eigen vector

# %%
G = np.array([[1,0], [1,3]])
G = np.linalg.eig(G)
(G)
# Out:
# (array([3., 1.]), array([[ 0.        ,  0.89442719],
#         [ 1.        , -0.4472136 ]]))

# %% [markdown]
# Eigen value

# %%
G = np.array([[1,0], [1,3]])
np.linalg.eigvals(G)
# Out:
# array([3., 1.])

# %%
x = np.array([[1,2,-3,4],[4,5,-3,2]])
print(f'data x =\n{x}')
c_x = np.cov(x)
print(f'Covarience ของ x คือ \n {c_x}')
# Out:
# data x =
# [[ 1  2 -3  4]
#  [ 4  5 -3  2]]
# Covarience ของ x คือ
#  [[ 8.66666667  7.66666667]
#  [ 7.66666667 12.66666667]]

# %%
W,V = np.linalg.eig(c_x)

# %%
print(W[1])
print(V[:,1])
# Out:
# 18.589909549336475
# [-0.6113829  -0.79133492]

# %% [markdown]
# Inverse Matrix
#
# inverse ของ $A$ เขียน $A^{-1}$
#
# นิยาม $A*A^{-1} = I =A^{-1}*A$

# %%
inv_c_x = np.linalg.inv(c_x)
print(c_x)
# Out:
# [[ 8.66666667  7.66666667]
#  [ 7.66666667 12.66666667]]

# %%
np.dot(c_x,inv_c_x)
# Out:
# array([[1.00000000e+00, 2.23193529e-16],
#        [1.26018779e-16, 1.00000000e+00]])

# %%
np.dot(inv_c_x,c_x)
# Out:
# array([[1.00000000e+00, 1.26018779e-16],
#        [2.23193529e-16, 1.00000000e+00]])

# %%
np.linalg.inv(inv_c_x)
# Out:
# array([[ 8.66666667,  7.66666667],
#        [ 7.66666667, 12.66666667]])

# %%
import pandas as pd
